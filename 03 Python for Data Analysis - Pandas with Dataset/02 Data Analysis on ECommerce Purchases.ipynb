# %% [markdown]
# ## Ecommerces Purchases

# %%
import pandas as pd

# %%
ecom = pd.read_csv('Ecommerce Purchases')

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom.head
# Out:
# <bound method NDFrame.head of                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecom.info
# Out:
# <bound method DataFrame.info of                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len(ecom.columns)
# Out:
# 14

# %%
ecom.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
len(ecom.index)
# Out:
# 10000

# %%
# ecom.columns()

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
ecom['Purchase Price'].mean()
# Out:
# 50.347302

# %%
ecom['Purchase Price'].mean
# Out:
# <bound method Series.mean of 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64>

# %%
ecom['Purchase Price'].max()
# Out:
# 99.99

# %%
ecom['Purchase Price'].min()
# Out:
# 0.0

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom.round()
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
print(ecom.columns)
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['Language']
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
ecom['Language'] == 'en'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Language, Length: 10000, dtype: bool

# %%
# sum() considers only True
sum(ecom['Language'] == 'en')
# Out:
# 1098

# %%
len(ecom['Language'] == 'en')
# Out:
# 10000

# %%
ecom[ecom['Language'] == 'en']
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %%
len(ecom[ecom['Language'] == 'en'])
# Out:
# 1098

# %%
ecom[ecom['Language'] == 'en'].head()
# Out:
#                                              Address    Lot AM or PM  \
# 11            349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12   733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22  625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26       5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                  USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
#
#                                          Browser Info  \
# 11  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 12  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_3 ...
# 22  Mozilla/5.0 (Windows 95) AppleWebKit/5342 (KHT...
# 26  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_3)...
# 31  Opera/8.84.(X11; Linux i686; sl-SI) Presto/2.9...
#
#                         Company       Credit Card CC Exp Date  \
# 11                   Kim-Oliver   869975209012056       06/26
# 12                 Moore-Martin  5115990487067905       05/26
# ...

# %%
ecom[ecom['Language'] == 'en'].head(3)
# Out:
#                                              Address    Lot AM or PM  \
# 11            349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12   733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22  625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
#
#                                          Browser Info       Company  \
# 11  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...    Kim-Oliver
# 12  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_3 ...  Moore-Martin
# 22  Mozilla/5.0 (Windows 95) AppleWebKit/5342 (KHT...   Burnett Ltd
#
#          Credit Card CC Exp Date  CC Security Code    CC Provider  \
# 11   869975209012056       06/26              9717   JCB 15 digit
# 12  5115990487067905       05/26               119  VISA 16 digit
# 22  3158663456056588       07/22               508       Discover
#
#                         Email                      Job      IP Address  \
# 11   johnnymiller@coleman.com  Diagnostic radiographer  128.222.40.234
# ...

# %%
len(ecom[ecom['Language'] == 'en'])
# Out:
# 1098

# %%
ecom[ecom['Language'] == 'en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
ecom[ecom['Language'] == 'en']['Language'].count()
# Out:
# 1098

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['Job']
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object

# %%
ecom['Job']=='Lawyer'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
ecom[ecom['Job']=='Lawyer']
# Out:
#                                                 Address    Lot AM or PM  \
# 470   9310 Bailey Mountain Apt. 832\nLake Jacqueline...  67 tQ       PM
# 508     5064 Nicole Circle\nJohnsonburgh, NM 78266-6283  53 rJ       PM
# 1275  4394 Sherry Row Suite 034\nSouth Rebecca, MD 6...  80 jP       PM
# 1569  91733 King Mountains Apt. 356\nSouth Tammy, NE...  20 Aa       AM
# 1682      5691 Fox Mountains\nDudleyside, GU 66765-2101  67 Bk       AM
# 2164  57897 Stacey Pass\nLake Jacquelinestad, MA 038...  61 DY       PM
# 2619   720 Laurie Plains Apt. 458\nChavezfurt, DE 05290  38 gp       AM
# 2935         816 Cheyenne Causeway\nHeidibury, FL 10365  70 nu       AM
# 3663       6218 Mendez Estate\nEast Kylemouth, MI 80812  63 BG       PM
# 3738   3921 Courtney River\nSouth Donaldmouth, AK 78115  85 Rh       AM
# 3966  3465 Hunter Streets Apt. 976\nMedinachester, W...  07 xf       PM
# 5053       88431 Thomas Stream\nMartinchester, WA 82488  19 fZ       PM
# ...

# %%
ecom[ecom['Job']=='Lawyer'].index
# Out:
# Index([ 470,  508, 1275, 1569, 1682, 2164, 2619, 2935, 3663, 3738, 3966, 5053,
#        5339, 5452, 5562, 5974, 6131, 6136, 6220, 7368, 7645, 8127, 8220, 8620,
#        8683, 8801, 8860, 9175, 9659, 9979],
#       dtype='int64')

# %%
ecom[ecom['Job']=='Lawyer'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 470 to 9979
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           30 non-null     object
#  1   Lot               30 non-null     object
#  2   AM or PM          30 non-null     object
#  3   Browser Info      30 non-null     object
#  4   Company           30 non-null     object
#  5   Credit Card       30 non-null     int64
#  6   CC Exp Date       30 non-null     object
#  7   CC Security Code  30 non-null     int64
#  8   CC Provider       30 non-null     object
#  9   Email             30 non-null     object
#  10  Job               30 non-null     object
#  11  IP Address        30 non-null     object
#  12  Language          30 non-null     object
#  13  Purchase Price    30 non-null     float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 3.5+ KB

# %%
ecom[ecom['Job']=='Lawyer']
# Out:
#                                                 Address    Lot AM or PM  \
# 470   9310 Bailey Mountain Apt. 832\nLake Jacqueline...  67 tQ       PM
# 508     5064 Nicole Circle\nJohnsonburgh, NM 78266-6283  53 rJ       PM
# 1275  4394 Sherry Row Suite 034\nSouth Rebecca, MD 6...  80 jP       PM
# 1569  91733 King Mountains Apt. 356\nSouth Tammy, NE...  20 Aa       AM
# 1682      5691 Fox Mountains\nDudleyside, GU 66765-2101  67 Bk       AM
# 2164  57897 Stacey Pass\nLake Jacquelinestad, MA 038...  61 DY       PM
# 2619   720 Laurie Plains Apt. 458\nChavezfurt, DE 05290  38 gp       AM
# 2935         816 Cheyenne Causeway\nHeidibury, FL 10365  70 nu       AM
# 3663       6218 Mendez Estate\nEast Kylemouth, MI 80812  63 BG       PM
# 3738   3921 Courtney River\nSouth Donaldmouth, AK 78115  85 Rh       AM
# 3966  3465 Hunter Streets Apt. 976\nMedinachester, W...  07 xf       PM
# 5053       88431 Thomas Stream\nMartinchester, WA 82488  19 fZ       PM
# ...

# %%
ecom[ecom['Job']=='Lawyer'].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
ecom[ecom['Job']=='Lawyer']['Job'].count()
# Out:
# 30

# %%
len(ecom[ecom['Job']=='Lawyer'])
# Out:
# 30

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom['AM or PM']
# Out:
# 0       PM
# 1       PM
# 2       PM
# 3       PM
# 4       AM
#         ..
# 9995    PM
# 9996    AM
# 9997    AM
# 9998    PM
# 9999    AM
# Name: AM or PM, Length: 10000, dtype: object

# %%
ecom['AM or PM']=='AM'.count
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: AM or PM, Length: 10000, dtype: bool

# %%
len(ecom[ecom['AM or PM']=='AM'])
# Out:
# 4932

# %%
len(ecom[ecom['AM or PM']=='PM'])
# Out:
# 5068

# %%
len(ecom[ecom['AM or PM']=='AM']) + len(ecom[ecom['AM or PM']=='AM'])
# Out:
# 9864

# %%
print(ecom.value_counts())
# Out:
# Address                                                Lot    AM or PM  Browser Info                                                                                                    Company                        Credit Card       CC Exp Date  CC Security Code  CC Provider    Email                        Job                                  IP Address       Language  Purchase Price
# 000 Jared Shoals Apt. 244\nRamirezmouth, IL 12450      55 Zz  PM        Mozilla/5.0 (compatible; MSIE 6.0; Windows CE; Trident/3.1)                                                     Garcia, Sanchez and Fox        3096295094562282  02/17        657               Discover       beltrancarmen@rogers.org     Biomedical engineer                  91.169.108.79    en        80.20             1
# ...

# %%
ecom['AM or PM']=='AM'.count
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: AM or PM, Length: 10000, dtype: bool

# %%
ecom[ecom['AM or PM']=='AM']
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# ...                                                 ...    ...      ...
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom[ecom['AM or PM']=='AM'].value_counts
# Out:
# <bound method DataFrame.value_counts of                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# ...                                                 ...    ...      ...
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom[ecom['AM or PM']=='AM'].value_counts()
# Out:
# Address                                                     Lot    AM or PM  Browser Info                                                                                                                                        Company                       Credit Card       CC Exp Date  CC Security Code  CC Provider                  Email                                  Job                                  IP Address       Language  Purchase Price
# 00009 Sharon Forks Apt. 078\nWest Sabrinabury, MA 45611     65 dS  AM        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_4) AppleWebKit/5320 (KHTML, like Gecko) Chrome/15.0.833.0 Safari/5320                                   Lopez, Barton and Miller      60423591589       04/17        362               VISA 16 digit                hhurst@gmail.com                       Development worker, community        254.48.96.123    fr        17.20             1
# ...

# %%
ecom['AM or PM'].unique()
# Out:
# array(['PM', 'AM'], dtype=object)

# %%
ecom['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['Job']
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object

# %%
ecom['Job'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object>

# %%
ecom['Job'].value_counts(5)
# Out:
# Job
# Interior and spatial designer    0.0031
# Lawyer                           0.0030
# Social researcher                0.0028
# Purchasing manager               0.0027
# Designer, jewellery              0.0027
#                                   ...
# Prison officer                   0.0007
# Editor, film/video               0.0006
# Actuary                          0.0006
# Information systems manager      0.0005
# Investment analyst               0.0005
# Name: proportion, Length: 623, dtype: float64

# %%
ecom['Job'].value_counts()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: count, Length: 623, dtype: int64

# %%
ecom['Job'].value_counts().head()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: count, dtype: int64

# %%
ecom['Job'].unique()
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['Lot']
# Out:
# 0       46 in
# 1       28 rn
# 2       94 vE
# 3       36 vm
# 4       20 IE
#         ...
# 9995    92 XI
# 9996    41 JY
# 9997    74 Zh
# 9998    74 cL
# 9999    64 Hr
# Name: Lot, Length: 10000, dtype: object

# %%
ecom[ecom['Lot'] == '90 WT']
# Out:
#                                                Address    Lot AM or PM  \
# 513  50398 Mccoy Rest Suite 597\nSouth Garyborough,...  90 WT       AM
#
#                                           Browser Info     Company  \
# 513  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_2 like M...  Bright PLC
#
#       Credit Card CC Exp Date  CC Security Code       CC Provider  \
# 513  630438419693       11/19               173  American Express
#
#                 Email              Job     IP Address Language  Purchase Price
# 513  jesse00@page.net  Energy engineer  156.70.208.94       ru            75.1

# %%
ecom[ecom['Lot'] == '90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
ecom[ecom['Lot'] == '90 WT']['Address']
# Out:
# 513    50398 Mccoy Rest Suite 597\nSouth Garyborough,...
# Name: Address, dtype: object

# %%
ecom[ecom['Lot'] == '90 WT'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 513 to 513
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           1 non-null      object
#  1   Lot               1 non-null      object
#  2   AM or PM          1 non-null      object
#  3   Browser Info      1 non-null      object
#  4   Company           1 non-null      object
#  5   Credit Card       1 non-null      int64
#  6   CC Exp Date       1 non-null      object
#  7   CC Security Code  1 non-null      int64
#  8   CC Provider       1 non-null      object
#  9   Email             1 non-null      object
#  10  Job               1 non-null      object
#  11  IP Address        1 non-null      object
#  12  Language          1 non-null      object
#  13  Purchase Price    1 non-null      float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 120.0+ bytes

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['Credit Card']
# Out:
# 0       6011929061123406
# 1       3337758169645356
# 2           675957666125
# 3       6011578504430710
# 4       6011456623207998
#               ...
# 9995     342945015358701
# 9996     210033169205009
# 9997    6011539787356311
# 9998     180003348082930
# 9999    4139972901927273
# Name: Credit Card, Length: 10000, dtype: int64

# %%
ecom['Credit Card'] == 4926535242672853
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Credit Card, Length: 10000, dtype: bool

# %%
ecom['Credit Card'] == '4926535242672853'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Credit Card, Length: 10000, dtype: bool

# %%
ecom[ecom['Credit Card'] == 4926535242672853 ]
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672853       09/21               188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %%
ecom[ecom['Credit Card'] == '4926535242672853' ]
# Out:
# Empty DataFrame
# Columns: [Address, Lot, AM or PM, Browser Info, Company, Credit Card, CC Exp Date, CC Security Code, CC Provider, Email, Job, IP Address, Language, Purchase Price]
# Index: []

# %%
ecom[ecom['Credit Card'] == 4926535242672853 ]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
ecom['CC Provider']
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
ecom[ecom['CC Provider'] =='American Express']
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 17    950 Jacqueline Village Apt. 592\nPort Kimberly...  23 Rh       PM
# 37           86777 Mary Crescent\nCarloshaven, KY 48326  10 LL       AM
# 45    096 Edwards Valleys Suite 917\nPerkinsberg, LA...  07 Cd       PM
# 51           735 Gaines Plains\nRyanfurt, GU 29451-6616  50 Ds       PM
# ...                                                 ...    ...      ...
# 9942           03874 Richard Isle\nNew Steven, TX 25541  13 An       PM
# 9944  67427 Mitchell Roads Apt. 905\nEast Christinev...  13 mI       AM
# 9965  2268 Austin Village Apt. 542\nWest Meghan, CA ...  03 hK       AM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...

# %%
len(ecom[ecom['CC Provider'] =='American Express'])
# Out:
# 849

# %%
ecom[ecom['CC Provider'] =='American Express']['Purchase Price']
# Out:
# 9       95.63
# 17      58.68
# 37      80.42
# 45      18.69
# 51      93.22
#         ...
# 9942     7.00
# 9944    17.13
# 9965    61.46
# 9973    83.30
# 9998    38.84
# Name: Purchase Price, Length: 849, dtype: float64

# %%
ecom[ecom['CC Provider'] =='American Express']['Purchase Price'] > 95
# Out:
# 9        True
# 17      False
# 37      False
# 45      False
# 51      False
#         ...
# 9942    False
# 9944    False
# 9965    False
# 9973    False
# 9998    False
# Name: Purchase Price, Length: 849, dtype: bool

# %%
ecom[ecom['CC Provider'] =='American Express']['Purchase Price'] > 95
# Out:
# 9        True
# 17      False
# 37      False
# 45      False
# 51      False
#         ...
# 9942    False
# 9944    False
# 9965    False
# 9973    False
# 9998    False
# Name: Purchase Price, Length: 849, dtype: bool

# %%
ecom[ecom['CC Provider'] =='American Express']['Purchase Price'] > 95
# Out:
# 9        True
# 17      False
# 37      False
# 45      False
# 51      False
#         ...
# 9942    False
# 9944    False
# 9965    False
# 9973    False
# 9998    False
# Name: Purchase Price, Length: 849, dtype: bool

# %%
ecom[ecom['CC Provider'] =='American Express']['Purchase Price']
# Out:
# 9       95.63
# 17      58.68
# 37      80.42
# 45      18.69
# 51      93.22
#         ...
# 9942     7.00
# 9944    17.13
# 9965    61.46
# 9973    83.30
# 9998    38.84
# Name: Purchase Price, Length: 849, dtype: float64

# %%
ecom[ecom['CC Provider'] =='American Express']['Purchase Price']
# Out:
# 9       95.63
# 17      58.68
# 37      80.42
# 45      18.69
# 51      93.22
#         ...
# 9942     7.00
# 9944    17.13
# 9965    61.46
# 9973    83.30
# 9998    38.84
# Name: Purchase Price, Length: 849, dtype: float64

# %%
ecom[(ecom['CC Provider'] =='American Express') & (ecom['Purchase Price']>95)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# ...

# %%
ecom[(ecom['CC Provider'] =='American Express') & (ecom['Purchase Price']>95)].index
# Out:
# Index([   9,  280,  372,  677,  766, 1225, 1381, 1385, 1568, 1727, 2146, 2264,
#        2267, 2642, 2828, 3291, 3349, 3619, 4071, 4569, 5385, 5655, 5692, 5814,
#        5875, 5895, 6026, 6524, 7239, 7381, 7416, 7514, 8233, 8381, 8408, 8434,
#        8817, 9168, 9856],
#       dtype='int64')

# %%
ecom[(ecom['CC Provider'] =='American Express') & (ecom['Purchase Price']>95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
ecom[(ecom['CC Provider'] =='American Express') & (ecom['Purchase Price']>95)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 9 to 9856
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           39 non-null     object
#  1   Lot               39 non-null     object
#  2   AM or PM          39 non-null     object
#  3   Browser Info      39 non-null     object
#  4   Company           39 non-null     object
#  5   Credit Card       39 non-null     int64
#  6   CC Exp Date       39 non-null     object
#  7   CC Security Code  39 non-null     int64
#  8   CC Provider       39 non-null     object
#  9   Email             39 non-null     object
#  10  Job               39 non-null     object
#  11  IP Address        39 non-null     object
#  12  Language          39 non-null     object
#  13  Purchase Price    39 non-null     float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 4.6+ KB

# %%
len(ecom[(ecom['CC Provider'] =='American Express') & (ecom['Purchase Price']>95)].index)
# Out:
# 39

# %%
ecom['CC Exp Date'].iloc

# %%
ecom['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
ecom['CC Exp Date'].iloc[0] #string
# Out:
# '02/20'

# %%
ecom['CC Exp Date'].iloc[0][3:]
# Out:
# '20'

# %%
ecom['CC Exp Date'].apply(lambda exp: exp[3:])
# Out:
# 0       20
# 1       18
# 2       19
# 3       24
# 4       25
#         ..
# 9995    22
# 9996    25
# 9997    21
# 9998    17
# 9999    19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
sum(ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25'))
# Out:
# 1033

# %%
ecom[ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25')]
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB       AM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
ecom[ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25')].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %%
exmpl = ecom['Email'].iloc[0]

# %%
exmpl
# Out:
# 'pdunlap@yahoo.com'

# %%
exmpl.split('@')
# Out:
# ['pdunlap', 'yahoo.com']

# %%
exmpl.split('@')[1]
# Out:
# 'yahoo.com'

# %%
ecom['Email'].apply(lambda email: email.split("@")[1])
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
ecom['Email'].apply(lambda email: email.split("@")[1]).value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: Email, Length: 10000, dtype: object>

# %%
ecom['Email'].apply(lambda email: email.split("@")[1]).value_counts()
# Out:
# Email
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: count, Length: 3416, dtype: int64

# %%
ecom['Email'].apply(lambda email: email.split("@")[1]).value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
ecom['Email'].apply(lambda email: email.split("@")[1]).value_counts().head(5)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %% [markdown]
# ## Thank You!
